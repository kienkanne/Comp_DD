# %%
from nexus.validate.rmsd import parse_dock6_pose_rmsds
from pathlib import Path

pose1 = Path("/localscratch/kbui/NexusMol/examples/artifacts/6W63_mol4_solvated/6W63_mol4_prepared_scored_pose_1.mol2")
pose2 = Path("/localscratch/kbui/NexusMol/examples/artifacts/6W63_mol4_solvated/6W63_mol4_prepared_scored_pose_2.mol2")

parse_dock6_pose_rmsds(pose1, pose2)
# Out:
# [12:36:31] /localscratch/kbui/NexusMol/examples/6W63_mol4_prepared_scored.pdbqt: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# [12:36:31] /localscratch/kbui/NexusMol/examples/6W63_mol4_prepared_scored.pdbqt: Warning - no explicit hydrogens in mol2 file but needed for formal charge estimation.
# ['2.624']
